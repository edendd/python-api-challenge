# %%
# Dependencies and Setup
import os
import csv
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import openweathermapy as ow
from pprint import pprint
import datetime

# Import API key
#Incorporated citipy to determine city based on latitude and longitude

from citipy import citipy
# Output File (CSV)
output_data_file = "C:/Users/edenh/OneDrive/Desktop/python-api-challenge/WeatherPy/cities.csv"

API_KEY = "dd6514b19742a5cd173b8f99de015cce"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []
country_codes = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1])
    city_name = city.city_name
    country_code = city.country_code
    
# If the city is unique, then add it to a our cities list & also add its corresponding country code
    if city_name not in cities:
        cities.append(city_name)
        country_codes.append(country_code)

# Print the city count to confirm sufficient count
print('The above script has generated {} different cities using random numbers.'.format(len(set(cities))))
# Out:
# The above script has generated 619 different cities using random numbers.

# %%
#create a dataframe to store all the cities and countries generated with citipy
df_countries = pd.DataFrame({'City': cities, 'Country': country_codes})

#add additional blank columns to store information from openweathermap api
df_countries['Latitude'] = ''
df_countries['Longitude'] = ''
df_countries['Temperature (F)'] = ''
df_countries['Humidity (%)'] = ''
df_countries['Cloudiness (%)'] = ''
df_countries['Wind Speed (mph)'] = ''
df_countries['Date'] = ''

# keeps count of those cities whose weather information is successfully obtained
city_count = 0

# initializing # of variables
api_call_count = 1 # count for API calls made to OpenWeatherAPI, max 60 counts allowed for free API calls
sets = 0 # counter to count the number of call sets
t0 = time.time() # get current time

#loop through all rows and fill in values for blank columns in dataframe
for index,row in df_countries.iterrows():
    city_name = row['City']
    country_id = row['Country']
    
    # create a dictionary to contain the query parameters
    search_parameters = {
        "q": str(city_name)+","+str(country_id),
        "units": "IMPERIAL",
        "mode": "json",
        "APPID": API_KEY
    }

    
    # URL for Weather map api call for cities
    target_url = "http://api.openweathermap.org/data/2.5/weather"
    country_info = requests.get(target_url, params = search_parameters).json()
    
    try:
        df_countries.loc[index,'Latitude'] = country_info['coord']['lat']
        df_countries.loc[index,'Longitude'] = country_info['coord']['lon']
        df_countries.loc[index,'Temperature (F)'] = country_info['main']['temp']
        df_countries.loc[index,'Humidity (%)'] = country_info['main']['humidity']
        df_countries.loc[index,'Cloudiness (%)'] = country_info['clouds']['all']
        df_countries.loc[index,'Wind Speed (mph)'] = country_info['wind']['speed']
        df_countries.loc[index, 'Date'] = country_info['dt']
 

       
        #print log for each city
        print(f'Processing Record {api_call_count} of Set {sets} | {city_name}' )
        
        city_count = city_count + 1 
    except KeyError:
        df_countries.loc[index,'Latitude'] = np.nan
        df_countries.loc[index,'Longitude'] = np.nan
        df_countries.loc[index,'Temperature (F)'] = np.nan
        df_countries.loc[index,'Humidity (%)'] = np.nan
        df_countries.loc[index,'Cloudiness (%)'] = np.nan
        df_countries.loc[index,'Wind Speed (mph)'] = np.nan
        df_countries.loc[index,'Date'] = np.nan
        print(f"Missing weather information for city named: {city_name} ...hence skipping")
    api_call_count = api_call_count + 1        
    if api_call_count == 51: #The OpenWeatherMap API limit is 60 calls/min
        t1 = time.time()
        api_call_count = 1 # reset it for next 50 calls
        sets = sets+1
        time.sleep(60-(t0-t1))
        t0 = time.time()
print(f"Processing successfully completed. Retrieved weather information for {city_count} cities")
# Out:
# Missing weather information for city named: illoqqortoormiut ...hence skipping
# Processing Record 2 of Set 0 | pevek
# Processing Record 3 of Set 0 | luderitz
# Missing weather information for city named: asau ...hence skipping
# Processing Record 5 of Set 0 | longyearbyen
# Processing Record 6 of Set 0 | ayagoz
# Processing Record 7 of Set 0 | ribeira grande
# Processing Record 8 of Set 0 | albany
# Processing Record 9 of Set 0 | butaritari
# Processing Record 10 of Set 0 | berlevag
# Processing Record 11 of Set 0 | saldanha
# Processing Record 12 of Set 0 | chuy
# Processing Record 13 of Set 0 | tuktoyaktuk
# Processing Record 14 of Set 0 | mitsamiouli
# Processing Record 15 of Set 0 | liuzhou
# Missing weather information for city named: mataura ...hence skipping
# Processing Record 17 of Set 0 | yangjiang
# Processing Record 18 of Set 0 | east london
# Processing Record 19 of Set 0 | lompoc
# Processing Record 20 of Set 0 | port alfred
# Missing weather information for city named: tumannyy ...hence skipping
# Processing Record 22 of Set 0 | busselton
# Missing weather information for city named: tsihombe ...hence skipping
# Processing Record 24 of Set 0 | villaba
# Processing Record 25 of Set 0 | hickory
# Processing Record 26 of Set 0 | rikitea
# Processing Record 27 of Set 0 | roma
# Processing Record 28 of Set 0 | tateyama
# Processing Record 29 of Set 0 | ushuaia
# Processing Record 30 of Set 0 | fuerte olimpo
# Processing Record 31 of Set 0 | puerto ayora
# Processing Record 32 of Set 0 | mar del plata
# Processing Record 33 of Set 0 | brownsville
# Processing Record 34 of Set 0 | vaini
# Missing weather information for city named: amderma ...hence skipping
# Processing Record 36 of Set 0 | chokurdakh
# Processing Record 37 of Set 0 | norman wells
# Processing Record 38 of Set 0 | esperance
# Missing weather information for city named: barentsburg ...hence skipping
# Processing Record 40 of Set 0 | avarua
# Processing Record 41 of Set 0 | tskaltubo
# Processing Record 42 of Set 0 | tondano
# Processing Record 43 of Set 0 | hermanus
# Processing Record 44 of Set 0 | tiksi
# Processing Record 45 of Set 0 | kodiak
# Processing Record 46 of Set 0 | jamestown
# Missing weather information for city named: uwayl ...hence skipping
# Processing Record 48 of Set 0 | rawson
# Processing Record 49 of Set 0 | belyy yar
# Processing Record 50 of Set 0 | westport
# Processing Record 1 of Set 1 | bambous virieux
# Processing Record 2 of Set 1 | atuona
# Missing weather information for city named: mata ...hence skipping
# Processing Record 4 of Set 1 | algeciras
# Processing Record 5 of Set 1 | grindavik
# Processing Record 6 of Set 1 | pangnirtung
# Processing Record 7 of Set 1 | berbera
# Processing Record 8 of Set 1 | cape town
# Processing Record 9 of Set 1 | toledo
# Processing Record 10 of Set 1 | fort nelson
# Processing Record 11 of Set 1 | santa cruz del sur
# Processing Record 12 of Set 1 | husavik
# Processing Record 13 of Set 1 | fushun
# Processing Record 14 of Set 1 | upernavik
# Processing Record 15 of Set 1 | isoka
# Processing Record 16 of Set 1 | amarante do maranhao
# Processing Record 17 of Set 1 | barrow
# Processing Record 18 of Set 1 | hobart
# Processing Record 19 of Set 1 | sisimiut
# Processing Record 20 of Set 1 | henties bay
# Processing Record 21 of Set 1 | saint george
# Processing Record 22 of Set 1 | hay river
# Processing Record 23 of Set 1 | pisco
# Processing Record 24 of Set 1 | paradise
# Processing Record 25 of Set 1 | naze
# Processing Record 26 of Set 1 | fomboni
# Missing weather information for city named: bure ...hence skipping
# Processing Record 28 of Set 1 | kautokeino
# Processing Record 29 of Set 1 | sioux lookout
# Processing Record 30 of Set 1 | katsuura
# Processing Record 31 of Set 1 | new norfolk
# Processing Record 32 of Set 1 | talnakh
# Processing Record 33 of Set 1 | santa fe
# Missing weather information for city named: airai ...hence skipping
# Processing Record 35 of Set 1 | khatanga
# Processing Record 36 of Set 1 | udachnyy
# Processing Record 37 of Set 1 | nanyamba
# Processing Record 38 of Set 1 | sao raimundo das mangabeiras
# Processing Record 39 of Set 1 | thompson
# Processing Record 40 of Set 1 | hasaki
# Processing Record 41 of Set 1 | axim
# Processing Record 42 of Set 1 | carnarvon
# Processing Record 43 of Set 1 | waingapu
# Processing Record 44 of Set 1 | port elizabeth
# Missing weather information for city named: umzimvubu ...hence skipping
# Processing Record 46 of Set 1 | vardo
# Missing weather information for city named: avera ...hence skipping
# Processing Record 48 of Set 1 | nelson bay
# Processing Record 49 of Set 1 | providencia
# Missing weather information for city named: vaitupu ...hence skipping
# Processing Record 1 of Set 2 | broken hill
# Processing Record 2 of Set 2 | hithadhoo
# Processing Record 3 of Set 2 | kapaa
# Processing Record 4 of Set 2 | touros
# Processing Record 5 of Set 2 | bonavista
# Processing Record 6 of Set 2 | coxim
# Processing Record 7 of Set 2 | bud
# Processing Record 8 of Set 2 | ulkan
# Processing Record 9 of Set 2 | marsa matruh
# Processing Record 10 of Set 2 | alanya
# Processing Record 11 of Set 2 | bluff
# Processing Record 12 of Set 2 | kushima
# Processing Record 13 of Set 2 | nome
# Processing Record 14 of Set 2 | nikolskoye
# Processing Record 15 of Set 2 | aripuana
# Processing Record 16 of Set 2 | rudbar
# Missing weather information for city named: kazalinsk ...hence skipping
# Missing weather information for city named: bobo dioulasso ...hence skipping
# Missing weather information for city named: sentyabrskiy ...hence skipping
# Processing Record 20 of Set 2 | ust-uda
# Processing Record 21 of Set 2 | deputatskiy
# Missing weather information for city named: taolanaro ...hence skipping
# Processing Record 23 of Set 2 | sao filipe
# Processing Record 24 of Set 2 | ruwi
# Missing weather information for city named: apollona ...hence skipping
# Processing Record 26 of Set 2 | qaanaaq
# Processing Record 27 of Set 2 | hilo
# Missing weather information for city named: doctor pedro p. pena ...hence skipping
# Processing Record 29 of Set 2 | dicabisagan
# Processing Record 30 of Set 2 | saskylakh
# Processing Record 31 of Set 2 | ushtobe
# Missing weather information for city named: bengkulu ...hence skipping
# Processing Record 33 of Set 2 | nuuk
# Missing weather information for city named: buqayq ...hence skipping
# Processing Record 35 of Set 2 | provideniya
# Processing Record 36 of Set 2 | coquimbo
# Processing Record 37 of Set 2 | lalsot
# Processing Record 38 of Set 2 | bredasdorp
# Processing Record 39 of Set 2 | makaha
# Processing Record 40 of Set 2 | santana
# Processing Record 41 of Set 2 | saint-augustin
# Processing Record 42 of Set 2 | saint-pierre
# Missing weather information for city named: samusu ...hence skipping
# Processing Record 44 of Set 2 | yellowknife
# Processing Record 45 of Set 2 | kamenka
# Processing Record 46 of Set 2 | koster
# Processing Record 47 of Set 2 | san roque
# Processing Record 48 of Set 2 | lorengau
# Missing weather information for city named: kofarnihon ...hence skipping
# Processing Record 50 of Set 2 | kharp
# Processing Record 1 of Set 3 | okitipupa
# Processing Record 2 of Set 3 | popondetta
# Processing Record 3 of Set 3 | monetnyy
# Processing Record 4 of Set 3 | kyra
# Processing Record 5 of Set 3 | sao jose da coroa grande
# Processing Record 6 of Set 3 | beloha
# Processing Record 7 of Set 3 | honiara
# Processing Record 8 of Set 3 | hit
# Processing Record 9 of Set 3 | samarai
# Processing Record 10 of Set 3 | sitka
# Processing Record 11 of Set 3 | port lincoln
# Processing Record 12 of Set 3 | hualmay
# Processing Record 13 of Set 3 | sao joao da barra
# Processing Record 14 of Set 3 | namatanai
# Processing Record 15 of Set 3 | meulaboh
# Processing Record 16 of Set 3 | coos bay
# Missing weather information for city named: belushya guba ...hence skipping
# Processing Record 18 of Set 3 | tasiilaq
# Processing Record 19 of Set 3 | hays
# Processing Record 20 of Set 3 | mahebourg
# Processing Record 21 of Set 3 | mount gambier
# Processing Record 22 of Set 3 | charters towers
# Processing Record 23 of Set 3 | castro
# Processing Record 24 of Set 3 | tocopilla
# Processing Record 25 of Set 3 | tezu
# Processing Record 26 of Set 3 | toora-khem
# Missing weather information for city named: mys shmidta ...hence skipping
# Processing Record 28 of Set 3 | teahupoo
# Processing Record 29 of Set 3 | lichuan
# Processing Record 30 of Set 3 | guerrero negro
# Processing Record 31 of Set 3 | cherskiy
# Processing Record 32 of Set 3 | taybad
# Processing Record 33 of Set 3 | nishihara
# Processing Record 34 of Set 3 | fortuna
# Missing weather information for city named: codrington ...hence skipping
# Missing weather information for city named: dolbeau ...hence skipping
# Processing Record 37 of Set 3 | gladstone
# Processing Record 38 of Set 3 | ghanzi
# Processing Record 39 of Set 3 | dunedin
# Processing Record 40 of Set 3 | cabras
# Processing Record 41 of Set 3 | yar-sale
# Processing Record 42 of Set 3 | leningradskiy
# Processing Record 43 of Set 3 | srednekolymsk
# Processing Record 44 of Set 3 | vestmannaeyjar
# Processing Record 45 of Set 3 | namibe
# Processing Record 46 of Set 3 | burnie
# Processing Record 47 of Set 3 | point pleasant
# Processing Record 48 of Set 3 | gainesville
# Processing Record 49 of Set 3 | aklavik
# Processing Record 50 of Set 3 | margate
# Processing Record 1 of Set 4 | punta arenas
# Processing Record 2 of Set 4 | teya
# Processing Record 3 of Set 4 | talara
# Processing Record 4 of Set 4 | upata
# Processing Record 5 of Set 4 | great yarmouth
# Processing Record 6 of Set 4 | dikson
# Processing Record 7 of Set 4 | amga
# Missing weather information for city named: krasnoyarsk-66 ...hence skipping
# Processing Record 9 of Set 4 | coihaique
# Processing Record 10 of Set 4 | clyde river
# Processing Record 11 of Set 4 | hohenau
# Processing Record 12 of Set 4 | homer
# Processing Record 13 of Set 4 | saint-philippe
# Processing Record 14 of Set 4 | montepuez
# Processing Record 15 of Set 4 | alice springs
# Missing weather information for city named: burica ...hence skipping
# Missing weather information for city named: camana ...hence skipping
# Processing Record 18 of Set 4 | cidreira
# Processing Record 19 of Set 4 | lagoa
# Processing Record 20 of Set 4 | coolum beach
# Processing Record 21 of Set 4 | kedrovyy
# Processing Record 22 of Set 4 | ponta do sol
# Processing Record 23 of Set 4 | okha
# Processing Record 24 of Set 4 | nanortalik
# Processing Record 25 of Set 4 | ukiah
# Processing Record 26 of Set 4 | ewa beach
# Missing weather information for city named: zolotinka ...hence skipping
# Processing Record 28 of Set 4 | balao
# Processing Record 29 of Set 4 | tamandare
# Processing Record 30 of Set 4 | tawala
# Processing Record 31 of Set 4 | vila franca do campo
# Missing weather information for city named: pafos ...hence skipping
# Processing Record 33 of Set 4 | konya
# Processing Record 34 of Set 4 | arona
# Processing Record 35 of Set 4 | victoria
# Processing Record 36 of Set 4 | taoudenni
# Processing Record 37 of Set 4 | sarangani
# Processing Record 38 of Set 4 | mantua
# Processing Record 39 of Set 4 | torbay
# Processing Record 40 of Set 4 | mogok
# Processing Record 41 of Set 4 | arraial do cabo
# Processing Record 42 of Set 4 | caravelas
# Processing Record 43 of Set 4 | yulara
# Processing Record 44 of Set 4 | izhma
# Processing Record 45 of Set 4 | socorro
# Processing Record 46 of Set 4 | redlands
# Processing Record 47 of Set 4 | labuhan
# Missing weather information for city named: toliary ...hence skipping
# Processing Record 49 of Set 4 | partizanske
# Processing Record 50 of Set 4 | bubaque
# Processing Record 1 of Set 5 | la ronge
# Processing Record 2 of Set 5 | lumberton
# Processing Record 3 of Set 5 | yumen
# Processing Record 4 of Set 5 | fairbanks
# Processing Record 5 of Set 5 | san jose
# Processing Record 6 of Set 5 | broome
# Processing Record 7 of Set 5 | itarema
# Processing Record 8 of Set 5 | kalabo
# Processing Record 9 of Set 5 | bonthe
# Processing Record 10 of Set 5 | geraldton
# Missing weather information for city named: aporawan ...hence skipping
# Processing Record 12 of Set 5 | tura
# Processing Record 13 of Set 5 | pontal do parana
# Processing Record 14 of Set 5 | lomonosov
# Processing Record 15 of Set 5 | freeport
# Processing Record 16 of Set 5 | chaozhou
# Processing Record 17 of Set 5 | shelburne
# Processing Record 18 of Set 5 | port-gentil
# Processing Record 19 of Set 5 | pochutla
# Processing Record 20 of Set 5 | wysokie mazowieckie
# Processing Record 21 of Set 5 | paamiut
# Processing Record 22 of Set 5 | inhambane
# Processing Record 23 of Set 5 | georgetown
# Processing Record 24 of Set 5 | beringovskiy
# Processing Record 25 of Set 5 | brae
# Processing Record 26 of Set 5 | makokou
# Processing Record 27 of Set 5 | san patricio
# Missing weather information for city named: maloshuyka ...hence skipping
# Processing Record 29 of Set 5 | praia da vitoria
# Processing Record 30 of Set 5 | berdigestyakh
# Processing Record 31 of Set 5 | anastacio
# Processing Record 32 of Set 5 | klaksvik
# Processing Record 33 of Set 5 | cayenne
# Processing Record 34 of Set 5 | khorinsk
# Processing Record 35 of Set 5 | koungou
# Missing weather information for city named: palabuhanratu ...hence skipping
# Processing Record 37 of Set 5 | bad frankenhausen
# Missing weather information for city named: saint anthony ...hence skipping
# Processing Record 39 of Set 5 | porto novo
# Processing Record 40 of Set 5 | bethel
# Missing weather information for city named: yanan ...hence skipping
# Processing Record 42 of Set 5 | sabzevar
# Processing Record 43 of Set 5 | nalut
# Processing Record 44 of Set 5 | ekibastuz
# Processing Record 45 of Set 5 | portobelo
# Processing Record 46 of Set 5 | port keats
# Processing Record 47 of Set 5 | mehamn
# Processing Record 48 of Set 5 | surab
# Processing Record 49 of Set 5 | vostok
# Processing Record 50 of Set 5 | severo-kurilsk
# Processing Record 1 of Set 6 | ancud
# Processing Record 2 of Set 6 | riwaka
# Processing Record 3 of Set 6 | pontes e lacerda
# Processing Record 4 of Set 6 | awjilah
# Processing Record 5 of Set 6 | havelock
# Processing Record 6 of Set 6 | arlit
# Processing Record 7 of Set 6 | ndioum
# Processing Record 8 of Set 6 | balezino
# Processing Record 9 of Set 6 | atar
# Processing Record 10 of Set 6 | mnogovershinnyy
# Processing Record 11 of Set 6 | port macquarie
# Processing Record 12 of Set 6 | sangar
# Processing Record 13 of Set 6 | mackay
# Processing Record 14 of Set 6 | sobolevo
# Missing weather information for city named: tanshui ...hence skipping
# Processing Record 16 of Set 6 | belmonte
# Processing Record 17 of Set 6 | santa maria
# Processing Record 18 of Set 6 | kruisfontein
# Processing Record 19 of Set 6 | ostrovnoy
# Processing Record 20 of Set 6 | iqaluit
# Processing Record 21 of Set 6 | haines junction
# Processing Record 22 of Set 6 | san cristobal
# Processing Record 23 of Set 6 | ahipara
# Missing weather information for city named: olafsvik ...hence skipping
# Processing Record 25 of Set 6 | bozoum
# Processing Record 26 of Set 6 | trincomalee
# Processing Record 27 of Set 6 | eregli
# Processing Record 28 of Set 6 | novyy urengoy
# Processing Record 29 of Set 6 | bontang
# Processing Record 30 of Set 6 | lahaina
# Processing Record 31 of Set 6 | canavieiras
# Processing Record 32 of Set 6 | lai
# Processing Record 33 of Set 6 | destin
# Missing weather information for city named: satitoa ...hence skipping
# Processing Record 35 of Set 6 | cervo
# Processing Record 36 of Set 6 | soyo
# Processing Record 37 of Set 6 | scarborough
# Processing Record 38 of Set 6 | wanaka
# Missing weather information for city named: bargal ...hence skipping
# Processing Record 40 of Set 6 | vestmanna
# Missing weather information for city named: barawe ...hence skipping
# Processing Record 42 of Set 6 | aden
# Processing Record 43 of Set 6 | lebu
# Processing Record 44 of Set 6 | padang
# Processing Record 45 of Set 6 | barcelos
# Missing weather information for city named: tambopata ...hence skipping
# Processing Record 47 of Set 6 | high prairie
# Processing Record 48 of Set 6 | dubbo
# Processing Record 49 of Set 6 | davila
# Processing Record 50 of Set 6 | mizan teferi
# Processing Record 1 of Set 7 | necochea
# Processing Record 2 of Set 7 | vila velha
# Processing Record 3 of Set 7 | huarmey
# Processing Record 4 of Set 7 | bandundu
# Processing Record 5 of Set 7 | taltal
# Processing Record 6 of Set 7 | marquette
# Missing weather information for city named: nizhneyansk ...hence skipping
# Processing Record 8 of Set 7 | letterkenny
# Processing Record 9 of Set 7 | cherepanovo
# Processing Record 10 of Set 7 | shajapur
# Processing Record 11 of Set 7 | faanui
# Processing Record 12 of Set 7 | semey
# Missing weather information for city named: tarudant ...hence skipping
# Processing Record 14 of Set 7 | constitucion
# Processing Record 15 of Set 7 | urucara
# Missing weather information for city named: lata ...hence skipping
# Processing Record 17 of Set 7 | dakar
# Processing Record 18 of Set 7 | jalu
# Processing Record 19 of Set 7 | ubinskoye
# Missing weather information for city named: faya ...hence skipping
# Processing Record 21 of Set 7 | kasongo-lunda
# Processing Record 22 of Set 7 | wagar
# Processing Record 23 of Set 7 | mujiayingzi
# Processing Record 24 of Set 7 | mount isa
# Processing Record 25 of Set 7 | abu kamal
# Processing Record 26 of Set 7 | micheweni
# Processing Record 27 of Set 7 | tarauaca
# Processing Record 28 of Set 7 | cockburn town
# Processing Record 29 of Set 7 | koumac
# Processing Record 30 of Set 7 | markova
# Processing Record 31 of Set 7 | semirom
# Missing weather information for city named: vila ...hence skipping
# Processing Record 33 of Set 7 | namie
# Processing Record 34 of Set 7 | harper
# Processing Record 35 of Set 7 | tiebissou
# Missing weather information for city named: khani ...hence skipping
# Processing Record 37 of Set 7 | araouane
# Processing Record 38 of Set 7 | ducheng
# Processing Record 39 of Set 7 | general macarthur
# Processing Record 40 of Set 7 | tartagal
# Processing Record 41 of Set 7 | balad
# Processing Record 42 of Set 7 | carupano
# Processing Record 43 of Set 7 | ken caryl
# Processing Record 44 of Set 7 | dargaville
# Processing Record 45 of Set 7 | nemuro
# Processing Record 46 of Set 7 | carauari
# Processing Record 47 of Set 7 | souillac
# Processing Record 48 of Set 7 | chegdomyn
# Processing Record 49 of Set 7 | luanda
# Processing Record 50 of Set 7 | kartaly
# Processing Record 1 of Set 8 | nhulunbuy
# Processing Record 2 of Set 8 | letka
# Processing Record 3 of Set 8 | port hedland
# Processing Record 4 of Set 8 | cabedelo
# Processing Record 5 of Set 8 | alakurtti
# Processing Record 6 of Set 8 | seabra
# Processing Record 7 of Set 8 | salalah
# Processing Record 8 of Set 8 | batemans bay
# Processing Record 9 of Set 8 | morgan city
# Processing Record 10 of Set 8 | rafai
# Processing Record 11 of Set 8 | mandalgovi
# Processing Record 12 of Set 8 | wattegama
# Processing Record 13 of Set 8 | guiratinga
# Processing Record 14 of Set 8 | swan hill
# Processing Record 15 of Set 8 | ahvaz
# Processing Record 16 of Set 8 | college
# Processing Record 17 of Set 8 | tupik
# Processing Record 18 of Set 8 | christchurch
# Processing Record 19 of Set 8 | cacequi
# Processing Record 20 of Set 8 | coahuayana
# Processing Record 21 of Set 8 | malpe
# Missing weather information for city named: cam pha ...hence skipping
# Processing Record 23 of Set 8 | flinders
# Processing Record 24 of Set 8 | zemio
# Processing Record 25 of Set 8 | barcelona
# Processing Record 26 of Set 8 | trinidad
# Processing Record 27 of Set 8 | manjacaze
# Missing weather information for city named: laguna ...hence skipping
# Processing Record 29 of Set 8 | yeppoon
# Processing Record 30 of Set 8 | tucumcari
# Processing Record 31 of Set 8 | enkoping
# Processing Record 32 of Set 8 | walvis bay
# Processing Record 33 of Set 8 | tayoltita
# Processing Record 34 of Set 8 | port-cartier
# Missing weather information for city named: galiwinku ...hence skipping
# Processing Record 36 of Set 8 | verkhnevilyuysk
# Processing Record 37 of Set 8 | pacific grove
# Processing Record 38 of Set 8 | qaqortoq
# Processing Record 39 of Set 8 | comodoro rivadavia
# Processing Record 40 of Set 8 | khash
# Processing Record 41 of Set 8 | neiafu
# Processing Record 42 of Set 8 | northam
# Processing Record 43 of Set 8 | talant
# Processing Record 44 of Set 8 | noyabrsk
# Processing Record 45 of Set 8 | raudeberg
# Processing Record 46 of Set 8 | waitati
# Missing weather information for city named: yaan ...hence skipping
# Processing Record 48 of Set 8 | general pico
# Processing Record 49 of Set 8 | thinadhoo
# Missing weather information for city named: aflu ...hence skipping
# Processing Record 1 of Set 9 | yen bai
# Processing Record 2 of Set 9 | ust-maya
# Processing Record 3 of Set 9 | bissau
# Processing Record 4 of Set 9 | evensk
# Processing Record 5 of Set 9 | kloulklubed
# Processing Record 6 of Set 9 | medicine hat
# Processing Record 7 of Set 9 | kirya
# Processing Record 8 of Set 9 | los llanos de aridane
# Processing Record 9 of Set 9 | cabo san lucas
# Processing Record 10 of Set 9 | sorland
# Missing weather information for city named: glubokoe ...hence skipping
# Processing Record 12 of Set 9 | benghazi
# Processing Record 13 of Set 9 | vilhena
# Missing weather information for city named: asfi ...hence skipping
# Processing Record 15 of Set 9 | macomer
# Missing weather information for city named: bara ...hence skipping
# Missing weather information for city named: taga ...hence skipping
# Processing Record 18 of Set 9 | ruston
# Processing Record 19 of Set 9 | penzance
# Processing Record 20 of Set 9 | troitsko-pechorsk
# Missing weather information for city named: lolua ...hence skipping
# Processing Record 22 of Set 9 | mombetsu
# Processing Record 23 of Set 9 | anloga
# Processing Record 24 of Set 9 | nuevo progreso
# Processing Record 25 of Set 9 | rio cuarto
# Processing Record 26 of Set 9 | champerico
# Processing Record 27 of Set 9 | bafia
# Processing Record 28 of Set 9 | mandaguacu
# Processing Record 29 of Set 9 | boa vista
# Processing Record 30 of Set 9 | rockport
# Processing Record 31 of Set 9 | yuanping
# Processing Record 32 of Set 9 | napierville
# Processing Record 33 of Set 9 | saint-francois
# Missing weather information for city named: humaita ...hence skipping
# Processing Record 35 of Set 9 | tsagan aman
# Processing Record 36 of Set 9 | ekhabi
# Processing Record 37 of Set 9 | quatre cocos
# Processing Record 38 of Set 9 | narsaq
# Processing Record 39 of Set 9 | pimentel
# Processing Record 40 of Set 9 | moindou
# Processing Record 41 of Set 9 | kuah
# Processing Record 42 of Set 9 | mabaruma
# Processing Record 43 of Set 9 | marienburg
# Processing Record 44 of Set 9 | alofi
# Processing Record 45 of Set 9 | kankan
# Processing Record 46 of Set 9 | farafangana
# Processing Record 47 of Set 9 | sur
# Processing Record 48 of Set 9 | arandas
# Processing Record 49 of Set 9 | chake chake
# Processing Record 50 of Set 9 | honningsvag
# Processing Record 1 of Set 10 | san carlos de bariloche
# Processing Record 2 of Set 10 | omboue
# Missing weather information for city named: tabiauea ...hence skipping
# Processing Record 4 of Set 10 | ilulissat
# Processing Record 5 of Set 10 | hervey bay
# Processing Record 6 of Set 10 | dongsheng
# Processing Record 7 of Set 10 | prieska
# Processing Record 8 of Set 10 | hami
# Processing Record 9 of Set 10 | minab
# Processing Record 10 of Set 10 | nieuw nickerie
# Processing Record 11 of Set 10 | batagay-alyta
# Processing Record 12 of Set 10 | alyangula
# Processing Record 13 of Set 10 | pimenta bueno
# Missing weather information for city named: grand river south east ...hence skipping
# Processing Record 15 of Set 10 | debre sina
# Processing Record 16 of Set 10 | kirakira
# Missing weather information for city named: jiddah ...hence skipping
# Missing weather information for city named: saint-georges ...hence skipping
# Missing weather information for city named: aktash ...hence skipping
# Processing Record 20 of Set 10 | esmeraldas
# Processing Record 21 of Set 10 | nichinan
# Processing Record 22 of Set 10 | madison
# Processing Record 23 of Set 10 | palmer
# Processing Record 24 of Set 10 | shenjiamen
# Processing Record 25 of Set 10 | merauke
# Processing Record 26 of Set 10 | tiznit
# Processing Record 27 of Set 10 | aykino
# Processing Record 28 of Set 10 | kaitangata
# Processing Record 29 of Set 10 | road town
# Processing Record 30 of Set 10 | sibolga
# Processing Record 31 of Set 10 | naryan-mar
# Processing Record 32 of Set 10 | kandrian
# Missing weather information for city named: gurskoye ...hence skipping
# Missing weather information for city named: raga ...hence skipping
# Processing Record 35 of Set 10 | mayor pablo lagerenza
# Processing Record 36 of Set 10 | cruzilia
# Processing Record 37 of Set 10 | zhigansk
# Processing Record 38 of Set 10 | payson
# Processing Record 39 of Set 10 | shiraoi
# Missing weather information for city named: urumqi ...hence skipping
# Processing Record 41 of Set 10 | sao gabriel da cachoeira
# Processing Record 42 of Set 10 | yeniseysk
# Missing weather information for city named: maimon ...hence skipping
# Processing Record 44 of Set 10 | agirish
# Processing Record 45 of Set 10 | ayolas
# Missing weather information for city named: san quintin ...hence skipping
# Missing weather information for city named: marcona ...hence skipping
# Processing Record 48 of Set 10 | acapulco
# Processing Record 49 of Set 10 | kulhudhuffushi
# Processing Record 50 of Set 10 | yugorsk
# Processing Record 1 of Set 11 | orchard homes
# Processing Record 2 of Set 11 | vaitape
# Processing Record 3 of Set 11 | tautira
# Missing weather information for city named: akyab ...hence skipping
# Processing Record 5 of Set 11 | poum
# Processing Record 6 of Set 11 | ihosy
# Processing Record 7 of Set 11 | joshimath
# Processing Record 8 of Set 11 | dosso
# Missing weather information for city named: saleaula ...hence skipping
# Processing Record 10 of Set 11 | rusape
# Processing Record 11 of Set 11 | banda aceh
# Processing Record 12 of Set 11 | hobyo
# Processing Record 13 of Set 11 | murray bridge
# Processing Record 14 of Set 11 | adrar
# Processing Record 15 of Set 11 | la rioja
# Processing Record 16 of Set 11 | baoding
# Processing Record 17 of Set 11 | la asuncion
# Processing Record 18 of Set 11 | cristalina
# Processing Record 19 of Set 11 | bilibino
# Processing Record 20 of Set 11 | mitchell
# Processing Record 21 of Set 11 | punta cardon
# Processing Record 22 of Set 11 | pringsewu
# Processing Record 23 of Set 11 | general roca
# Processing Record 24 of Set 11 | pambujan
# Processing Record 25 of Set 11 | mackenzie
# Processing Record 26 of Set 11 | savonlinna
# Processing Record 27 of Set 11 | kahului
# Processing Record 28 of Set 11 | linqu
# Processing Record 29 of Set 11 | vila do maio
# Missing weather information for city named: hvammstangi ...hence skipping
# Processing Record 31 of Set 11 | iralaya
# Processing Record 32 of Set 11 | adra
# Processing Record 33 of Set 11 | marystown
# Processing Record 34 of Set 11 | shelbyville
# Missing weather information for city named: daxian ...hence skipping
# Processing Record 36 of Set 11 | rincon
# Processing Record 37 of Set 11 | portland
# Processing Record 38 of Set 11 | isangel
# Processing Record 39 of Set 11 | takoradi
# Processing Record 40 of Set 11 | encheng
# Processing Record 41 of Set 11 | baker city
# Processing Record 42 of Set 11 | bhavnagar
# Missing weather information for city named: attawapiskat ...hence skipping
# Processing Record 44 of Set 11 | kudahuvadhoo
# Processing Record 45 of Set 11 | sorong
# Processing Record 46 of Set 11 | hofn
# Processing Record 47 of Set 11 | bodden town
# Processing Record 48 of Set 11 | ladario
# Processing Record 49 of Set 11 | brainerd
# Processing Record 50 of Set 11 | bundaberg
# Processing Record 1 of Set 12 | jacareacanga
# Processing Record 2 of Set 12 | koulamoutou
# Processing Record 3 of Set 12 | maningrida
# Processing Record 4 of Set 12 | richards bay
# Processing Record 5 of Set 12 | chernigovka
# Processing Record 6 of Set 12 | kaeo
# Processing Record 7 of Set 12 | marawi
# Missing weather information for city named: kobojango ...hence skipping
# Processing Record 9 of Set 12 | maragogi
# Missing weather information for city named: kamenskoye ...hence skipping
# Processing Record 11 of Set 12 | bani walid
# Missing weather information for city named: saleilua ...hence skipping
# Missing weather information for city named: el alto ...hence skipping
# Missing weather information for city named: louisbourg ...hence skipping
# Processing Record 15 of Set 12 | mbuji-mayi
# Processing Record 16 of Set 12 | oktyabrskoye
# Processing Record 17 of Set 12 | ust-nera
# Processing Record 18 of Set 12 | chapais
# Processing Record 19 of Set 12 | liverpool
# Processing successfully completed. Retrieved weather information for 536 cities

# %%
#change all data recieved from openweathermap api to numerical data
df_countries['Latitude'] = pd.to_numeric(df_countries['Latitude'])
df_countries['Longitude'] = pd.to_numeric(df_countries['Longitude'])
df_countries['Temperature (F)'] = pd.to_numeric(df_countries['Temperature (F)'])
df_countries['Humidity (%)'] = pd.to_numeric(df_countries['Humidity (%)'])
df_countries['Cloudiness (%)'] = pd.to_numeric(df_countries['Cloudiness (%)'])
df_countries['Wind Speed (mph)'] = pd.to_numeric(df_countries['Wind Speed (mph)'])

#display dataframe df_countries after openweathermap api calls removing those with NaNs elements
df_countries = df_countries.dropna()

# Reorder columns as we're interested in for the final DataFrame
df_countries = df_countries[["City", "Cloudiness (%)", "Country", "Date", "Humidity (%)","Latitude","Longitude",

                       "Temperature (F)", "Wind Speed (mph)"]]

print(df_countries.count()) # displays the count of rows
print(df_countries.head(20)) # displays first 20 records
df_countries.dtypes # displays the Dataype of dataframe
df_countries.to_csv(output_data_file, encoding="utf-8", index=False)
# Out:
# City                536
# Cloudiness (%)      536
# Country             536
# Date                536
# Humidity (%)        536
# Latitude            536
# Longitude           536
# Temperature (F)     536
# Wind Speed (mph)    536
# dtype: int64
#               City  Cloudiness (%) Country        Date  Humidity (%)  \
# 1            pevek            18.0      ru  1574641638          86.0
# 2         luderitz             0.0      na  1574641639          73.0
# 4     longyearbyen            75.0      sj  1574641639          78.0
# 5           ayagoz           100.0      kz  1574641639          83.0
# 6   ribeira grande            99.0      pt  1574641639          92.0
# 7           albany            90.0      au  1574641639          67.0
# 8       butaritari            90.0      ki  1574641639          74.0
# 9         berlevag            97.0      no  1574641639          76.0
# 10        saldanha            56.0      za  1574641640          82.0
# 11            chuy             0.0      uy  1574641640          69.0
# 12     tuktoyaktuk            90.0      ca  1574641640          85.0
# 13     mitsamiouli            20.0      km  1574641640          78.0
# 14         liuzhou            60.0      cn  1574641640          65.0
# 16       yangjiang             0.0      cn  1574641641          62.0
# 17     east london            68.0      za  1574641503          70.0
# 18          lompoc             1.0      us  1574641563          30.0
# 19     port alfred            49.0      za  1574641641          86.0
# 21       busselton             0.0      au  1574641641          58.0
# 23         villaba            99.0      ph  1574641642          76.0
# 24         hickory             1.0      us  1574641642          93.0
#
#     Latitude  Longitude  Temperature (F)  Wind Speed (mph)
# 1      69.70     170.27           -12.23              3.51
# 2     -26.65      15.16            61.93             29.24
# 4      78.22      15.64            14.00              2.24
# 5      47.96      80.43            16.25              2.64
# 6      38.52     -28.70            66.20             28.10
# 7     -35.02     117.88            57.20              6.93
# 8       3.07     172.79            83.70              7.40
# 9      70.86      29.09            38.32             19.42
# 10    -33.01      17.94            55.40              1.12
# 11    -33.69     -53.46            60.84             13.24
# 12     69.44    -133.03            10.40             13.87
# 13    -11.38      43.28            80.60              8.05
# 14     24.32     109.41            62.04             15.75
# 16     21.85     111.96            69.08              4.29
# 17    -33.02      27.91            65.93              6.93
# 18     34.64    -120.46            67.89             10.29
# 19    -33.59      26.89            61.00              4.00
# 21    -33.64     115.35            63.39              3.00
# 23     11.21     124.39            81.32              2.28
# 24     35.73     -81.34            41.31              3.36

# %%
# Plot the Data LatitudevsTemperature Plot
plt.figure(figsize=(8,5))
plt.scatter(df_countries["Latitude"], df_countries["Temperature (F)"], color='gray', alpha=0.5)
plt.grid()
plt.xlabel('Latitude')
plt.ylabel('Temperature (F)')
plt.title(f'City Latitude vs Temperature ({datetime.datetime.now().strftime("%D")})')
plt.savefig("C:/Users/edenh/OneDrive/Desktop/python-api-challenge/WeatherPy/LatVsTemp.png")
plt.show()

# %%
# Plotting the Data - Latitude vs. Humidity Plot
plt.figure(figsize=(8,5))
plt.scatter(df_countries["Latitude"], df_countries["Humidity (%)"], color='gray', alpha=0.5)
plt.ylim(10,120)
plt.grid()
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title(f'City Latitude vs Humidity ({datetime.datetime.now().strftime("%D")})')
plt.savefig("C:/Users/edenh/OneDrive/Desktop/python-api-challenge/WeatherPy/LatVsHumidity.png")
plt.show()

# %%
# Plotting the Data - Latitude vs. Cloudiness Plot
plt.figure(figsize=(8,5))
plt.scatter(df_countries["Latitude"], df_countries["Cloudiness (%)"], color='gray', alpha=0.5)
plt.grid()
plt.ylim(-20,(df_countries["Cloudiness (%)"].max()+10))
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title(f'City Latitude vs Cloudiness ({datetime.datetime.now().strftime("%D")})')
plt.savefig("C:/Users/edenh/OneDrive/Desktop/python-api-challenge/WeatherPy/LatVsCloudiness.png")
plt.show()

# %%
# Plotting the Data - Latitude vs. Wind Speed Plot
plt.figure(figsize=(8,5))
plt.scatter(df_countries["Latitude"], df_countries["Wind Speed (mph)"], color='gray', alpha=0.5)
plt.grid()
plt.ylim((df_countries["Wind Speed (mph)"].min()-5),(df_countries["Wind Speed (mph)"].max()+5))
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title(f'City Latitude vs Wind Speed ({datetime.datetime.now().strftime("%D")})')
plt.savefig("C:/Users/edenh/OneDrive/Desktop/python-api-challenge/WeatherPy/LatVsWind.png")
plt.show()
